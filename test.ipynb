# %%
from agent import CNNModel, CNNPolicy
import numpy as np
import random
from rl_config import RLConfig
import torch

# %%
sample_input = np.random.rand(1, RLConfig.FRAMES_STACK * RLConfig.CHANNELS, RLConfig.FRAME_WIDTH, RLConfig.FRAME_HEIGHT)
sample_tensor = torch.from_numpy(sample_input).float()

# %%
sample_input.shape
# Out:
# (1, 15, 84, 84)

# %%
cnn_model = CNNModel(RLConfig)

# %%
cnn_model(sample_tensor)
# Out:
# tensor([[0.0386, 0.9614]], grad_fn=<SoftmaxBackward0>)
